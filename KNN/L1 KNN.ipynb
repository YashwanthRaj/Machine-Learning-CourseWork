# %%
# Importing pands library 

import pandas as pd

# %%
# Reading the data and storing the data in variable called "data", then changing the date from normal string to date format

data = pd.read_csv('weather.csv', parse_dates=True, index_col=0)

# %%
# Visualizing column names and dataset

data.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# Date
# 2008-02-01     19.5     22.4      15.6          6.2       0.0         NaN
# 2008-02-02     19.5     25.6       6.0          3.4       2.7         NaN
# 2008-02-03     21.6     24.5       6.6          2.4       0.1         NaN
# 2008-02-04     20.2     22.8      18.8          2.2       0.0         NaN
# 2008-02-05     19.7     25.7      77.4          NaN       0.0         NaN
#
#             WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  \
# Date                                                           ...
# 2008-02-01            NaN          S        SSW          17.0  ...
# 2008-02-02            NaN          W          E           9.0  ...
# 2008-02-03            NaN        ESE        ESE          17.0  ...
# 2008-02-04            NaN        NNE          E          22.0  ...
# 2008-02-05            NaN        NNE          W          11.0  ...
#
# ...

# %%
# Visualizing column indexes

data.index
# Out:
# DatetimeIndex(['2008-02-01', '2008-02-02', '2008-02-03', '2008-02-04',
#                '2008-02-05', '2008-02-06', '2008-02-07', '2008-02-08',
#                '2008-02-09', '2008-02-10',
#                ...
#                '2017-06-16', '2017-06-17', '2017-06-18', '2017-06-19',
#                '2017-06-20', '2017-06-21', '2017-06-22', '2017-06-23',
#                '2017-06-24', '2017-06-25'],
#               dtype='datetime64[ns]', name='Date', length=3337, freq=None)

# %%
# Taking only required columns from uploaded dataset and saving in new variabe name

dataset = data[['Humidity3pm', 'Pressure3pm', 'RainTomorrow']]

# %%
dataset.head()
# Out:
#             Humidity3pm  Pressure3pm RainTomorrow
# Date
# 2008-02-01         84.0       1017.4          Yes
# 2008-02-02         73.0       1016.4          Yes
# 2008-02-03         86.0       1015.6          Yes
# 2008-02-04         90.0       1011.8          Yes
# 2008-02-05         74.0       1004.8          Yes

# %%
# Importing math plot library for graphs and stuff

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Plotting the graph, below "=="No"" will show all points where rain has not occured
fig, ax = plt.subplots()

dataset[dataset['RainTomorrow']=='No'].plot.scatter(x="Humidity3pm", y="Pressure3pm", c='b', alpha =0.25, ax=ax)
dataset[dataset['RainTomorrow']=='Yes'].plot.scatter(x="Humidity3pm", y="Pressure3pm", c='r', alpha =0.25, ax=ax)
# Out:
# <AxesSubplot:xlabel='Humidity3pm', ylabel='Pressure3pm'>

# %%
# Importing libraries required for KNN

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# Cleaning the dataset

dataset_clean = dataset.dropna()
len(dataset), len(dataset_clean)
# Out:
# (3337, 3309)

# %%
# Splitting the determining values from label
X = dataset_clean[['Humidity3pm', 'Pressure3pm']]
y = dataset_clean['RainTomorrow']

# Changing the values of dataset lable into 0 and 1
y = np.array([0 if value == 'No' else 1 for value in y])

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
# Splitting the dataset into training and testing 
# random state for randomly selecting the values 

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Model Building
neigh = KNeighborsClassifier()
neigh.fit(X_train, y_train)

# Testing the accuracy
y_pred = neigh.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# C:\Users\yashw\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.8067632850241546

# %%
# Times when it is not raining 
sum(y == 0)/len(y)
# Out:
# 0.7407071622846781

# %%
# Times when it is raining 
sum(y == 1)/len(y)
# Out:
# 0.25929283771532186

# %%
X_map = np.random.rand(10000, 2)
X_map = X_map*(100, 50) + (0, 990)

# %%
fig, ax = plt.subplots()

y_map = neigh.predict(X_map)

ax.scatter(x=X_map[:,0], y=X_map[:,1], c=y_map, alpha=.25)
# Out:
# C:\Users\yashw\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\yashw\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
# Finding the values of K

scores = []
for k in range(1, 100):
    neigh = KNeighborsClassifier(n_neighbors=k)
    neigh.fit(X_train, y_train)
    y_pred = neigh.predict(X_test)
    score = accuracy_score(y_test, y_pred)
    scores.append(score)
# Out:
# C:\Users\yashw\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
# Plot the scores, Now from here we can find K value

fig, ax = plt.subplots()

ax.plot(scores)

# %%
# From the above graph we can Infer that K value can be 4 or 6 to achieve the maximum accuracy
